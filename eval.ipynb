    (0.8, 0.5): [78.94800327301026, 94.57600471496582, [18207, 16509, 15284]],
    (0.8, 0.6): [79.11000328063965, 94.63000465393067, [18207, 12179, 19614]],
    (0.8, 0.7): [79.25800365447998, 94.6980047607422, [18207, 7360, 24433]],
    (0.8, 0.8): [79.35800327301025, 94.72800457000733, [18207, 0, 31793]],
    (0.9, 0.0): [77.54200313568116, 93.84800449371338, [1556, 48444, 0]],
    (0.9, 0.1): [77.62600296020508, 93.89800445556641, [1556, 47836, 608]],
    (0.9, 0.2): [77.88000316619873, 94.16400447845459, [1556, 45298, 3146]],
    (0.9, 0.3): [78.32400356292725, 94.42200462341309, [1556, 41677, 6767]],
    (0.9, 0.4): [78.69400325775146, 94.54800426483155, [1556, 37682, 10762]],
    (0.9, 0.5): [78.96600326538086, 94.61800453186035, [1556, 33160, 15284]],
    (0.9, 0.6): [79.12600345611573, 94.67200469970703, [1556, 28830, 19614]],
    (0.9, 0.7): [79.27200328826905, 94.73800498962402, [1556, 24011, 24433]],
    (0.9, 0.8): [79.37400325775147, 94.76800476074219, [1556, 16651, 31793]],
    (0.9, 0.9): [79.4140033340454, 94.79200447082519, [1556, 0, 48444]],
    (1.0, 0.1): [77.62000339508057, 93.91000453948975, [0, 49392, 608]],
    (1.0, 0.2): [77.87400321960449, 94.17600456237793, [0, 46854, 3146]],
    (1.0, 0.3): [78.31600311279297, 94.43200454711913, [0, 43233, 6767]],
    (1.0, 0.4): [78.68800338745118, 94.56000457763672, [0, 39238, 10762]],
    (1.0, 0.5): [78.96400337219238, 94.63000461578369, [0, 34716, 15284]],
    (1.0, 0.6): [79.12000328063965, 94.68400470733643, [0, 30386, 19614]],
    (1.0, 0.7): [79.26800327301025, 94.7480046081543, [0, 25567, 24433]],
    (1.0, 0.8): [79.36800323486328, 94.7800047302246, [0, 18207, 31793]],
    (1.0, 0.9): [79.40800357818604, 94.80400421142578, [0, 1556, 48444]],
}

non_adaptive_no_info_sel_dict = {
    (0.0, 0.0): [71.44200298309326, 90.27200439453125, [50000, 0, 0]],
    (1.0, 0.0): [77.53600315093995, 93.86000484466553, [0, 50000, 0]],
    (1.0, 1.0): [79.4080035018921, 94.81000476837158, [0, 0, 50000]],
}

# %%
cf_df = [pd.DataFrame(c) for c in cf_list]
deit_df = pd.DataFrame(deit_list)
result_df = pd.DataFrame(
    [
        [
            (811039104 * i[2][0] + 2909431296 * i[2][1] + 8426119680 * i[2][2]) / 50000,
            i[0],
        ]
        for i in result_dict.values()
    ]
)
non_adaptive_df = pd.DataFrame(
    [
        [
            (811039104 * i[2][0] + 2909431296 * i[2][1] + 8426119680 * i[2][2]) / 50000,
            i[0],
        ]
        for i in non_adaptive_dict.values()
    ]
)
result_no_info_sel_df = pd.DataFrame(
    [
        [
            (811039104 * i[2][0] + 4176089856 * i[2][1] + 16371843840 * i[2][2]) / 50000,
            i[0],
        ]
        for i in result_no_info_sel_dict.values()
    ]
)
non_adaptive_no_info_sel_df = pd.DataFrame(
    [
        [
            (811039104 * i[2][0] + 4176089856 * i[2][1] + 16371843840 * i[2][2]) / 50000,
            i[0],
        ]
        for i in non_adaptive_no_info_sel_dict.values()
    ]
)

# %%
fig, ax = plt.subplots()
sns.lineplot(
    x=cf_df[0][0],
    y=cf_df[0][1],
    color=sns.color_palette("Set3")[2],
    legend=False,
    ax=ax,
)
sns.lineplot(
    x=cf_df[1][0],
    y=cf_df[1][1],
    color=sns.color_palette("Set3")[2],
    legend=False,
    ax=ax,
)
sns.scatterplot(
    x=deit_df[0],
    y=deit_df[1],
    color=sns.color_palette("Set3")[3],
    linewidth=0,
    size=1,
    legend=False,
    ax=ax,
)
sns.lineplot(x=deit_df[0], y=deit_df[1], color=sns.color_palette("Set3")[3], ax=ax)
sns.scatterplot(
    x=result_df[0],
    y=result_df[1],
    color=sns.color_palette("Set3")[4],
    linewidth=0,
    size=1,
    legend=False,
    ax=ax,
)
sns.scatterplot(
    x=non_adaptive_df[0],
    y=non_adaptive_df[1],
    color=sns.color_palette("Set3")[0],
    linewidth=0,
    size=1,
    legend=False,
    ax=ax,
)
sns.lineplot(
    x=non_adaptive_df[0],
    y=non_adaptive_df[1],
    color=sns.color_palette("Set3")[0],
    ax=ax,
)
ax.legend(
    handles=[
        Line2D(
            [0],
            [0],
            marker="o",
            color=c,
            linewidth=0,
        )
        for c in [
            sns.color_palette("Set3")[2],
            sns.color_palette("Set3")[3],
            sns.color_palette("Set3")[4],
            sns.color_palette("Set3")[0],
        ]
    ],
    labels=["CF-ViT", "DeiT", "ours", "ours (non-adaptive)"],
    loc="lower right",
)
plt.xlim(0, 9e9)
plt.ylim(71, 82)
plt.yticks(list(range(71, 82)) + [82])
plt.xlabel("FLOPs")
plt.ylabel("top-1 testing accuracy %")
plt.savefig("cf_eval.svg")
plt.savefig("cf_eval.png")

# %%
fig, ax = plt.subplots()
sns.scatterplot(
    x=result_df[0],
    y=result_df[1],
    color=sns.color_palette("Set3")[4],
    linewidth=0,
    size=1,
    legend=False,
    ax=ax,
)
sns.scatterplot(
    x=non_adaptive_df[0],
    y=non_adaptive_df[1],
    color=sns.color_palette("Set3")[4],
    linewidth=0,
    size=1,
    legend=False,
    ax=ax,
)
sns.scatterplot(
    x=result_no_info_sel_df[0],
    y=result_no_info_sel_df[1],
    color=sns.color_palette("Set3")[5],
    linewidth=0,
    size=1,
    legend=False,
    ax=ax,
)
sns.scatterplot(
    x=non_adaptive_no_info_sel_df[0],
    y=non_adaptive_no_info_sel_df[1],
    color=sns.color_palette("Set3")[5],
    linewidth=0,
    size=1,
    legend=False,
    ax=ax,
)
ax.legend(
    handles=[
        Line2D(
            [0],
            [0],
            marker="o",
            color=c,
            linewidth=0,
        )
        for c in [
            sns.color_palette("Set3")[4],
            sns.color_palette("Set3")[5],
        ]
    ],
    labels=["ours", "ours (no info. selection)"],
    loc="lower right",
)
plt.xlim(0, 1.7e10)
plt.ylim(71, 82)
plt.yticks(list(range(71, 82)) + [82])
plt.xlabel("FLOPs")
plt.ylabel("top-1 testing accuracy %")
plt.savefig("cf_eval_2.svg")
plt.savefig("cf_eval_2.png")
